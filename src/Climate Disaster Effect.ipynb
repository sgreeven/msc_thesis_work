# %%
import analysis
import sys
sys.path.append(r'C:\Users\Sebas\Documents\GitHub\EMAworkbench\src')

# %%
% matplotlib inline

import seaborn as sns
import matplotlib.pyplot as plt

sns.set_style('whitegrid')
sns.set_palette("deep")

# fig = plt.figure()
# ax = fig.add_subplot(111)
# plt.show()

# %%
import numpy as np

from analysis.plotting import lines, envelopes
from analysis.plotting_util import VIOLIN, KDE
from expWorkbench import load_results
from expWorkbench import ema_logging

# %%
import matplotlib.pyplot as plt

from analysis.pairs_plotting import pairs_lines, pairs_scatter, pairs_density
from expWorkbench.util import load_results

# ema_logging.log_to_stderr(level=ema_logging.DEFAULT_LEVEL)

# %%
ema_logging.log_to_stderr(ema_logging.INFO)

results = load_results(r'./data/disaster effect 1000 exp 100 rep.tar.gz')
# Out:
# [INFO/MainProcess] results loaded succesfully from ./data/disaster effect 1000 exp 100 rep.tar.gz

# %%
experiments, outcomes = results

models = set(experiments['model'])

grouped_results = {}
for model in models:
    logical = experiments['model']==model
    
    temp_experiments = experiments[logical]
    temp_outcomes = {key:value[logical] for key, value in outcomes.items()}
    grouped_results[model] = temp_experiments, temp_outcomes

ooi = 'CumulativeGHGreduction_mean'
models = list(models)
ooi_dif = grouped_results[models[0]][1][ooi] - grouped_results[models[1]][1][ooi]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style('whitegrid')

fig = plt.figure()
ax = fig.add_subplot(111)
ax.hist(ooi_dif[:,-1], bins=100)
plt.show()

# %%
from analysis.plotting import envelopes

envelopes(results, group_by='model', outcomes_to_show=ooi, fill=True, density='kde')
# Out:
# C:\Users\Sebas\Documents\GitHub\EMAworkbench\src\analysis\plotting_util.py:445: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if time==None:
# (<matplotlib.figure.Figure at 0x195f5be0>,
#  {'CumulativeGHGreduction_mean': <matplotlib.axes._subplots.AxesSubplot at 0x19655da0>,
#   'CumulativeGHGreduction_mean_density': <matplotlib.axes._subplots.AxesSubplot at 0x1a5237f0>})

# %%
from analysis import prim
from analysis.prim import Prim
from expWorkbench import ema_logging

# %%
import numpy.lib.recfunctions as rf

# %%
experiments =  rf.drop_fields(grouped_results[models[0]][0], 'model')

# %%
experiments = results

data = ooi_dif

fig = plt.figure()
ax = fig.add_subplot(111)
ax.plot(np.median(data, axis=0), label = 'mean')
ax.fill_between(np.arange(0, data.shape[1]),np.min(data, axis=0), np.max(data, axis=0), alpha=0.2)
ax.plot(np.percentile(data, 25, axis=0), label='first quartile')
ax.plot(np.percentile(data, 75, axis=0), label='third quartile')

ax.legend()
plt.show()

# %%
def classify(outcomes):
    outcome = outcomes['ooi_dif'][:,-1]
    classes = np.zeros(outcome.shape)
    classes[outcome>75] = 1
    return classes

prim_obj = Prim(results, classify, threshold=0.8)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-38-271313bb3a0c> in <module>()
#       5     return classes
#       6
# ----> 7 prim_obj = Prim(results, classify, threshold=0.8)
#
# C:\Users\Sebas\Documents\GitHub\EMAworkbench\src\analysis\prim.pyc in __init__(self, results, classify, obj_function, peel_alpha, paste_alpha, mass_min, threshold, threshold_type, incl_unc)
#     613             self.y = results[1][classify]
#     614         elif callable(classify):
# --> 615             self.y = classify(results[1])
#     616         else:
#     617             raise TypeError("unknown type for classify")
#
# <ipython-input-38-271313bb3a0c> in classify(outcomes)
#       1 def classify(outcomes):
# ----> 2     outcome = outcomes['ooi_dif'][:,-1]
#       3     classes = np.zeros(outcome.shape)
#       4     classes[outcome>75] = 1
#       5     return classes
#
# KeyError: 'ooi_dif'
