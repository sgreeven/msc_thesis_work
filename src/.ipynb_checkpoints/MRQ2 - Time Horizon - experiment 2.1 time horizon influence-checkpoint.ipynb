# %% [markdown]
# # Single uncertainty sensititivy analysis - Time Horizon Uncertainty
# * EMA Society's response to climate change
# * Name: Sebastiaan Greeven
# * Date: 12-5-2015
# #### Introduction
# This notebook contains the single uncertainty sensitivity analysis of the time horizon uncertainty.
#
# 1. Initialisation of the analysis
# 2. Visualisation of the sensitivity analysis
# 3. PRIM analysis

# %% [markdown]
# #1. Initialisation of the analysis

# %%
import analysis
import sys
sys.path.append(r'C:\Users\Sebas\Documents\GitHub\EMAworkbench\src')

# %%
% matplotlib inline

import seaborn as sns
import matplotlib.pyplot as plt

sns.set_style('whitegrid')
sns.set_palette("deep")

# fig = plt.figure()
# ax = fig.add_subplot(111)
# plt.show()

# %%
import numpy as np

from analysis.plotting import lines, envelopes
from analysis.plotting_util import VIOLIN, KDE
from expWorkbench import load_results
from expWorkbench import ema_logging

import mpld3

# %%
import matplotlib.pyplot as plt

from analysis.pairs_plotting import pairs_lines, pairs_scatter, pairs_density
from expWorkbench.util import load_results

# ema_logging.log_to_stderr(level=ema_logging.DEFAULT_LEVEL)

# %%
from analysis import prim
from analysis.prim import Prim
from expWorkbench import ema_logging

# %%
ema_logging.log_to_stderr(ema_logging.INFO)

results = load_results(r'./data/time horizon 1000 exp 100 rep.tar.gz')
# Out:
# [INFO/MainProcess] results loaded succesfully from ./data/time horizon 1000 exp 100 rep.tar.gz

# %% [markdown]
# #2. Visualisation of the sensitivity analysis

# %%
experiments, outcomes = results

models = set(experiments['model'])

grouped_results = {}
for model in models:
    logical = experiments['model']==model
    
    temp_experiments = experiments[logical]
    temp_outcomes = {key:value[logical] for key, value in outcomes.items()}
    grouped_results[model] = temp_experiments, temp_outcomes

oois = outcomes.keys()
    
for ooi in oois:
    models = list(models)
    ooi_dif = grouped_results[models[0]][1][ooi] - grouped_results[models[1]][1][ooi]
    fig = plt.figure()
    ax = fig.add_subplot(111)
    ax.hist(ooi_dif[:,-1], bins=20)
    ax.set_ylabel(ooi)
    ax.set_xlabel('Difference')
    plt.show()
    envelopes(results, group_by='model', outcomes_to_show=ooi, fill=True, density='kde')
# Out:
# C:\Users\Sebas\Documents\GitHub\EMAworkbench\src\analysis\plotting_util.py:445: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if time==None:

# %% [markdown]
# #3. PRIM analysis

# %%
import numpy.lib.recfunctions as rf

# %%
experiments =  rf.drop_fields(grouped_results[models[0]][0], 'model')

# %%
ooi_dif = grouped_results[models[0]][1]['CumulativeGHGreduction_mean'] - grouped_results[models[1]][1]['CumulativeGHGreduction_mean']

# %%
data = ooi_dif

fig = plt.figure()
ax = fig.add_subplot(111)
ax.plot(np.median(data, axis=0), label = 'mean')
ax.fill_between(np.arange(0, data.shape[1]),np.min(data, axis=0), np.max(data, axis=0), alpha=0.2)
ax.plot(np.percentile(data, 25, axis=0), label='first quartile')
ax.plot(np.percentile(data, 75, axis=0), label='third quartile')

ax.legend()
plt.show()

# %%
temp_outcomes = {'dif':ooi_dif}
results = experiments, temp_outcomes

def classify(data):
    outcome = data['dif'][:,-1]
    classes = np.zeros(outcome.shape)
    classes[outcome>8] = 1
    return classes

prim_obj = Prim(results, classify, threshold=0.8)

# %%
box1 = prim_obj.find_box()
box1.show_tradeoff()
mpld3.display()
# Out:
# [INFO/MainProcess] 1000 points remaining, containing 592 cases of interest
# [INFO/MainProcess] mean: 1.0, mass: 0.114, coverage: 0.192567567568, density: 1.0 restricted_dimensions: 7.0
# <style>
#
#             table
#             {
#               border-collapse: collapse;
#             }
#             th
#             {
#               background-color:  rgba(255,255,255,0.6);;;
#             }
#             td
#             {
#               background-color: rgba(255,255,255,0.6);;
#             }
#             table, th, td
#             {
#               font-family:Tahoma, Tahoma, sans-serif;
#               font-size: 16px;
#               border: 1px solid black;
#               text-align: right;
#             }
#
# </style>
#
# <div id="fig_el3843633362562378140574"></div>
# <script>
# function mpld3_load_lib(url, callback){
#   var s = document.createElement('script');
#   s.src = url;
#   s.async = true;
#   s.onreadystatechange = s.onload = callback;
#   s.onerror = function(){console.warn("failed to load library " + url);};
#   document.getElementsByTagName("head")[0].appendChild(s);
# }
#
# if(typeof(mpld3) !== "undefined" && mpld3._mpld3IsLoaded){
#    // already loaded: just create the figure
#    !function(mpld3){
#
#     mpld3.register_plugin("htmltooltip", HtmlTooltipPlugin);
#     HtmlTooltipPlugin.prototype = Object.create(mpld3.Plugin.prototype);
#     HtmlTooltipPlugin.prototype.constructor = HtmlTooltipPlugin;
#     HtmlTooltipPlugin.prototype.requiredProps = ["id"];
#     HtmlTooltipPlugin.prototype.defaultProps = {labels:null, hoffset:0, voffset:10};
#     function HtmlTooltipPlugin(fig, props){
#         mpld3.Plugin.call(this, fig, props);
#     };
#
#     HtmlTooltipPlugin.prototype.draw = function(){
#        var obj = mpld3.get_element(this.props.id);
#        var labels = this.props.labels;
#        var tooltip = d3.select("body").append("div")
#                     .attr("class", "mpld3-tooltip")
#                     .style("position", "absolute")
#                     .style("z-index", "10")
#                     .style("visibility", "hidden");
#
#        obj.elements()
#            .on("mouseover", function(d, i){
#                               tooltip.html(labels[i])
#                                      .style("visibility", "visible");})
#            .on("mousemove", function(d, i){
#                     tooltip
#                       .style("top", d3.event.pageY + this.props.voffset + "px")
#                       .style("left",d3.event.pageX + this.props.hoffset + "px");
#                  }.bind(this))
#            .on("mouseout",  function(d, i){
#                            tooltip.style("visibility", "hidden");});
#     };
#
#        mpld3.draw_figure("fig_el3843633362562378140574", {"axes": [{"xlim": [0.0, 1.2], "yscale": "linear", "axesbg": "#FFFFFF", "texts": [{"v_baseline": "hanging", "h_anchor": "middle", "color": "#262626", "text": "coverage", "coordinates": "axes", "zorder": 3, "alpha": 1, "fontsize": 11.0, "position": [0.5, -0.068426197458455532], "rotation": -0.0, "id": "el384432608144"}, {"v_baseline": "auto", "h_anchor": "middle", "color": "#262626", "text": "density", "coordinates": "axes", "zorder": 3, "alpha": 1, "fontsize": 11.0, "position": [-0.070459509408602128, 0.5], "rotation": -90.0, "id": "el384456934960"}], "zoomable": true, "images": [], "xdomain": [0.0, 1.2], "ylim": [0.0, 1.2], "paths": [], "sharey": [], "sharex": [], "axesbgalpha": null, "axes": [{"scale": "linear", "tickformat": null, "grid": {"color": "#CCCCCC", "alpha": 1.0, "dasharray": "10,0", "gridOn": true}, "fontsize": 10.0, "position": "bottom", "nticks": 7, "tickvalues": null}, {"scale": "linear", "tickformat": null, "grid": {"color": "#CCCCCC", "alpha": 1.0, "dasharray": "10,0", "gridOn": true}, "fontsize": 10.0, "position": "left", "nticks": 7, "tickvalues": null}], "lines": [], "markers": [], "id": "el384432417704", "ydomain": [0.0, 1.2], "collections": [{"paths": [[[[0.0, -0.5], [0.13260155, -0.5], [0.25978993539242673, -0.44731684579412084], [0.3535533905932738, -0.3535533905932738], [0.44731684579412084, -0.25978993539242673], [0.5, -0.13260155], [0.5, 0.0], [0.5, 0.13260155], [0.44731684579412084, 0.25978993539242673], [0.3535533905932738, 0.3535533905932738], [0.25978993539242673, 0.44731684579412084], [0.13260155, 0.5], [0.0, 0.5], [-0.13260155, 0.5], [-0.25978993539242673, 0.44731684579412084], [-0.3535533905932738, 0.3535533905932738], [-0.44731684579412084, 0.25978993539242673], [-0.5, 0.13260155], [-0.5, 0.0], [-0.5, -0.13260155], [-0.44731684579412084, -0.25978993539242673], [-0.3535533905932738, -0.3535533905932738], [-0.25978993539242673, -0.44731684579412084], [-0.13260155, -0.5], [0.0, -0.5]], ["M", "C", "C", "C", "C", "C", "C", "C", "C", "Z"]]], "edgecolors": ["#000000"], "edgewidths": [0.3], "offsets": "data01", "yindex": 1, "id": "el384472776488", "pathtransforms": [[4.969039949999533, 0.0, 0.0, 4.969039949999533, 0.0, 0.0]], "pathcoordinates": "display", "offsetcoordinates": "data", "zorder": 1, "xindex": 0, "alphas": [null], "facecolors": ["#081D58", "#243996", "#243996", "#206BAE", "#2CA0C1", "#2CA0C1", "#2CA0C1", "#2CA0C1", "#63C2BF", "#63C2BF", "#63C2BF", "#63C2BF", "#63C2BF", "#63C2BF", "#63C2BF", "#63C2BF", "#B2E0B6", "#E6F5B1", "#FFFFD9", "#FFFFD9", "#FFFFD9", "#FFFFD9", "#FFFFD9"]}], "xscale": "linear", "bbox": [0.125, 0.125, 0.62, 0.77500000000000002]}, {"xlim": [0.0, 1.0], "yscale": "linear", "axesbg": "#FFFFFF", "texts": [{"v_baseline": "hanging", "h_anchor": "middle", "color": "#262626", "text": "nr. of restricted dimensions", "coordinates": "axes", "zorder": 3, "alpha": 1, "fontsize": 11.0, "position": [2.1055107526881685, 0.5], "rotation": -90.0, "id": "el384429399120"}], "zoomable": false, "images": [], "xdomain": [0.0, 1.0], "ylim": [0.0, 1.0], "paths": [], "sharey": [], "sharex": [], "axesbgalpha": null, "axes": [{"scale": "linear", "tickformat": "", "grid": {"gridOn": false}, "fontsize": null, "position": "bottom", "nticks": 0, "tickvalues": []}, {"scale": "linear", "tickformat": null, "grid": {"gridOn": false}, "fontsize": 10.0, "position": "right", "nticks": 8, "tickvalues": [0.0625, 0.1875, 0.3125, 0.4375, 0.5625, 0.6875, 0.8125, 0.9375]}], "lines": [], "markers": [], "id": "el384429396992", "ydomain": [0.0, 1.0], "collections": [{"paths": [[[[0.0, 0.0], [1.0, 0.0], [1.0, 0.125], [0.0, 0.125], [0.0, 0.0]], ["M", "L", "L", "L", "L"]], [[[0.0, 0.125], [1.0, 0.125], [1.0, 0.25], [0.0, 0.25], [0.0, 0.125]], ["M", "L", "L", "L", "L"]], [[[0.0, 0.25], [1.0, 0.25], [1.0, 0.375], [0.0, 0.375], [0.0, 0.25]], ["M", "L", "L", "L", "L"]], [[[0.0, 0.375], [1.0, 0.375], [1.0, 0.5], [0.0, 0.5], [0.0, 0.375]], ["M", "L", "L", "L", "L"]] ...

# %%
box1.inspect(2)
box1.inspect(3)
box1.inspect(7)
# Out:
# coverage    0.959459
# density     0.629712
# mass        0.902000
# mean        0.629712
# res dim     1.000000
# Name: 2, dtype: float64
#
#                               box 2
#                                 min        max  qp values
# SDTimeHorizonDistribution  0.018352  18.039882   0.011294
#
# coverage    0.609797
# density     0.807606
# mass        0.447000
# mean        0.807606
# res dim     2.000000
# Name: 3, dtype: float64
#                                           box 3
#                                             min           max     qp values
# ClimateDisasterIncreaseMitigation  set([False])  set([False])  2.221995e-16
# SDTimeHorizonDistribution            0.01835166      18.03988   0.003151264
#
# coverage    0.540541
# density     0.886427
# mass        0.361000
# mean        0.886427
# res dim     3.000000
# Name: 7, dtype: float64
#                                           box 7
#                                             min           max     qp values
# ClimateDisasterIncreaseMitigation  set([False])  set([False])  6.739829e-20
# SDTimeHorizonDistribution            0.01835166      17.19088  2.859338e-05
# ImpactFactor                          0.8001594      1.149787   0.000314656

# %%
box1.inspect(7, style='graph')
plt.show()

# %%
from analysis.plotting_util import BOXPLOT

indices = box1.yi

all_indices = np.arange(experiments.shape[0])
logical = np.ones((all_indices.shape[0],), dtype=np.bool)
logical[indices] = 0
out_box = all_indices[logical]

gs = {}
gs['in box'] = indices
gs['out box'] = out_box
# gs['all'] = all_indices

envelopes(results, outcomes_to_show=['dif'], group_by='index', grouping_specifiers=gs, fill=True, density=BOXPLOT)
plt.show()

# %%
ooi_dif = grouped_results[models[0]][1]['AnnualGHGreduction_mean'] - grouped_results[models[1]][1]['AnnualGHGreduction_mean']

# %%
data = ooi_dif

fig = plt.figure()
ax = fig.add_subplot(111)
ax.plot(np.median(data, axis=0), label = 'mean')
ax.fill_between(np.arange(0, data.shape[1]),np.min(data, axis=0), np.max(data, axis=0), alpha=0.2)
ax.plot(np.percentile(data, 25, axis=0), label='first quartile')
ax.plot(np.percentile(data, 75, axis=0), label='third quartile')

ax.legend()
plt.show()

# %%
temp_outcomes = {'dif':ooi_dif}
results = experiments, temp_outcomes

def classify(data):
    outcome = data['dif'][:,-1]
    classes = np.zeros(outcome.shape)
    classes[outcome<-15] = 1
    return classes

prim_obj = Prim(results, classify, threshold=0.8)

# %%
box1 = prim_obj.find_box()
box1.show_tradeoff()
mpld3.display()
# Out:
# [INFO/MainProcess] 1000 points remaining, containing 257 cases of interest
# [INFO/MainProcess] mean: 1.0, mass: 0.064, coverage: 0.249027237354, density: 1.0 restricted_dimensions: 12.0
# <style>
#
#             table
#             {
#               border-collapse: collapse;
#             }
#             th
#             {
#               background-color:  rgba(255,255,255,0.6);;;
#             }
#             td
#             {
#               background-color: rgba(255,255,255,0.6);;
#             }
#             table, th, td
#             {
#               font-family:Tahoma, Tahoma, sans-serif;
#               font-size: 16px;
#               border: 1px solid black;
#               text-align: right;
#             }
#
# </style>
#
# <div id="fig_el3844384455603923430291"></div>
# <script>
# function mpld3_load_lib(url, callback){
#   var s = document.createElement('script');
#   s.src = url;
#   s.async = true;
#   s.onreadystatechange = s.onload = callback;
#   s.onerror = function(){console.warn("failed to load library " + url);};
#   document.getElementsByTagName("head")[0].appendChild(s);
# }
#
# if(typeof(mpld3) !== "undefined" && mpld3._mpld3IsLoaded){
#    // already loaded: just create the figure
#    !function(mpld3){
#
#     mpld3.register_plugin("htmltooltip", HtmlTooltipPlugin);
#     HtmlTooltipPlugin.prototype = Object.create(mpld3.Plugin.prototype);
#     HtmlTooltipPlugin.prototype.constructor = HtmlTooltipPlugin;
#     HtmlTooltipPlugin.prototype.requiredProps = ["id"];
#     HtmlTooltipPlugin.prototype.defaultProps = {labels:null, hoffset:0, voffset:10};
#     function HtmlTooltipPlugin(fig, props){
#         mpld3.Plugin.call(this, fig, props);
#     };
#
#     HtmlTooltipPlugin.prototype.draw = function(){
#        var obj = mpld3.get_element(this.props.id);
#        var labels = this.props.labels;
#        var tooltip = d3.select("body").append("div")
#                     .attr("class", "mpld3-tooltip")
#                     .style("position", "absolute")
#                     .style("z-index", "10")
#                     .style("visibility", "hidden");
#
#        obj.elements()
#            .on("mouseover", function(d, i){
#                               tooltip.html(labels[i])
#                                      .style("visibility", "visible");})
#            .on("mousemove", function(d, i){
#                     tooltip
#                       .style("top", d3.event.pageY + this.props.voffset + "px")
#                       .style("left",d3.event.pageX + this.props.hoffset + "px");
#                  }.bind(this))
#            .on("mouseout",  function(d, i){
#                            tooltip.style("visibility", "hidden");});
#     };
#
#        mpld3.draw_figure("fig_el3844384455603923430291", {"axes": [{"xlim": [0.0, 1.2], "yscale": "linear", "axesbg": "#FFFFFF", "texts": [{"v_baseline": "hanging", "h_anchor": "middle", "color": "#262626", "text": "coverage", "coordinates": "axes", "zorder": 3, "alpha": 1, "fontsize": 11.0, "position": [0.5, -0.068426197458455532], "rotation": -0.0, "id": "el384438508064"}, {"v_baseline": "auto", "h_anchor": "middle", "color": "#262626", "text": "density", "coordinates": "axes", "zorder": 3, "alpha": 1, "fontsize": 11.0, "position": [-0.070459509408602128, 0.5], "rotation": -90.0, "id": "el384441113120"}], "zoomable": true, "images": [], "xdomain": [0.0, 1.2], "ylim": [0.0, 1.2], "paths": [], "sharey": [], "sharex": [], "axesbgalpha": null, "axes": [{"scale": "linear", "tickformat": null, "grid": {"color": "#CCCCCC", "alpha": 1.0, "dasharray": "10,0", "gridOn": true}, "fontsize": 10.0, "position": "bottom", "nticks": 7, "tickvalues": null}, {"scale": "linear", "tickformat": null, "grid": {"color": "#CCCCCC", "alpha": 1.0, "dasharray": "10,0", "gridOn": true}, "fontsize": 10.0, "position": "left", "nticks": 7, "tickvalues": null}], "lines": [], "markers": [], "id": "el384438448024", "ydomain": [0.0, 1.2], "collections": [{"paths": [[[[0.0, -0.5], [0.13260155, -0.5], [0.25978993539242673, -0.44731684579412084], [0.3535533905932738, -0.3535533905932738], [0.44731684579412084, -0.25978993539242673], [0.5, -0.13260155], [0.5, 0.0], [0.5, 0.13260155], [0.44731684579412084, 0.25978993539242673], [0.3535533905932738, 0.3535533905932738], [0.25978993539242673, 0.44731684579412084], [0.13260155, 0.5], [0.0, 0.5], [-0.13260155, 0.5], [-0.25978993539242673, 0.44731684579412084], [-0.3535533905932738, 0.3535533905932738], [-0.44731684579412084, 0.25978993539242673], [-0.5, 0.13260155], [-0.5, 0.0], [-0.5, -0.13260155], [-0.44731684579412084, -0.25978993539242673], [-0.3535533905932738, -0.3535533905932738], [-0.25978993539242673, -0.44731684579412084], [-0.13260155, -0.5], [0.0, -0.5]], ["M", "C", "C", "C", "C", "C", "C", "C", "C", "Z"]]], "edgecolors": ["#000000"], "edgewidths": [0.3], "offsets": "data01", "yindex": 1, "id": "el384455430664", "pathtransforms": [[4.969039949999533, 0.0, 0.0, 4.969039949999533, 0.0, 0.0]], "pathcoordinates": "display", "offsetcoordinates": "data", "zorder": 1, "xindex": 0, "alphas": [null], "facecolors": ["#081D58", "#1B2C7F", "#1B2C7F", "#1B2C7F", "#1B2C7F", "#1B2C7F", "#1B2C7F", "#1B2C7F", "#1B2C7F", "#1B2C7F", "#1B2C7F", "#1B2C7F", "#1B2C7F", "#1B2C7F", "#1B2C7F", "#1B2C7F", "#24419A", "#24419A", "#24419A", "#225DA7", "#1E80B8", "#1E80B8", "#1E80B8", "#289DC1", "#40B5C3", "#68C4BE", "#68C4BE", "#68C4BE", "#97D6B8", "#C6E8B4", "#DFF2B2", "#F2FABD", "#F2FABD", "#FFFFD9", "#FFFFD9", "#FFFFD9"]}], "xscale": "linear", "bbox": [0.125, 0.125, 0.62, 0.77500000000000002]}, {"xlim": [0.0, 1.0], "yscale": "linear", "axesbg": "#FFFFFF", "texts": [{"v_baseline": "hanging", "h_anchor": "middle", "color": "#262626", "text": "nr. of restricted dimensions", "coordinates": "axes", "zorder": 3, "alpha": 1, "fontsize": 11.0, "position": [2.4170943304007793, 0.5], "rotation": -90.0, "id": "el384427546328"}], "zoomable": false, "images": [], "xdomain": [0.0, 1.0], "ylim": [0.0, 1.0], "paths": [], "sharey": [], "sharex": [], "axesbgalpha": null, "axes": [{"scale": "linear", "tickformat": "", "grid": {"gridOn": false}, "fontsize": null, "position": "bottom", "nticks": 0, "tickvalues": []}, {"scale": "linear", "tickformat": null, "grid": {"gridOn": false}, "fontsize": 10.0, "position": "right", "nticks": 13, "tickvalues": [0.038461538461538464, 0.11538461538461539, 0.19230769230769232, 0.26923076923076927, 0.34615384615384615, 0.42307692307692313, 0.5, 0.57692307692307698, 0.65384615384615385, 0.73076923076923084, 0.80769230769230771, 0.88461538461538469, 0.96153846153846156]}], "lines": [], "markers": [], "id": "el384455433744", "ydomain": [0.0, 1.0], "collections": [{"paths": [[[[0.0, 0.0], [1.0, 0.0], [1.0, 0.076923076923076 ...

# %%
box1.inspect(22)
box1.inspect(23)
# Out:
# coverage    0.813230
# density     0.657233
# mass        0.318000
# mean        0.657233
# res dim     4.000000
# Name: 22, dtype: float64
#
#                                box 22
#                                   min        max     qp values
# ImpactFactor                 0.800159   0.983298  1.516749e-32
# MitigationEnforcementFactor  0.336828   0.999682  3.113564e-03
# SDTimeHorizonDistribution    0.018352  17.300519  3.108959e-02
# PredictionError              0.012440   0.299938  2.538781e-01
#
# coverage    0.490272
# density     0.777778
# mass        0.162000
# mean        0.777778
# res dim     5.000000
# Name: 23, dtype: float64
#                                            box 23                        \
#                                               min                   max
# ImpactFactor                            0.8001594             0.9832978
# GameTheory                   set(["Cooperative"])  set(["Cooperative"])
# MitigationEnforcementFactor             0.3368284             0.9996822
# SDTimeHorizonDistribution              0.01835166              17.30052
# PredictionError                        0.01243964             0.2999379
#
#
#                                 qp values
# ImpactFactor                 2.281427e-22
# GameTheory                   0.0005742787
# MitigationEnforcementFactor    0.01831264
# SDTimeHorizonDistribution       0.1718809
# PredictionError                 0.5198898

# %%
box1.select(22)
box1.drop_restriction('PredictionError')
box1.inspect(style='graph')
plt.show()

# %%
box1.select(23)
box1.drop_restriction('PredictionError')
box1.drop_restriction('SDTimeHorizonDistribution')
box1.inspect(style='graph')
plt.show()

# %%
temp_outcomes = {'dif':ooi_dif}
results = experiments, temp_outcomes

def classify(data):
    outcome = data['dif'][:,50]
    classes = np.zeros(outcome.shape)
    classes[outcome>25] = 1
    return classes

prim_obj = Prim(results, classify, threshold=0.8)

# %%
box1 = prim_obj.find_box()
box1.show_tradeoff()
mpld3.display()
# Out:
# [INFO/MainProcess] 1000 points remaining, containing 184 cases of interest
# [INFO/MainProcess] mean: 0.913793103448, mass: 0.058, coverage: 0.288043478261, density: 0.913793103448 restricted_dimensions: 11.0
# <style>
#
#             table
#             {
#               border-collapse: collapse;
#             }
#             th
#             {
#               background-color:  rgba(255,255,255,0.6);;;
#             }
#             td
#             {
#               background-color: rgba(255,255,255,0.6);;
#             }
#             table, th, td
#             {
#               font-family:Tahoma, Tahoma, sans-serif;
#               font-size: 16px;
#               border: 1px solid black;
#               text-align: right;
#             }
#
# </style>
#
# <div id="fig_el3844323435841248781594"></div>
# <script>
# function mpld3_load_lib(url, callback){
#   var s = document.createElement('script');
#   s.src = url;
#   s.async = true;
#   s.onreadystatechange = s.onload = callback;
#   s.onerror = function(){console.warn("failed to load library " + url);};
#   document.getElementsByTagName("head")[0].appendChild(s);
# }
#
# if(typeof(mpld3) !== "undefined" && mpld3._mpld3IsLoaded){
#    // already loaded: just create the figure
#    !function(mpld3){
#
#     mpld3.register_plugin("htmltooltip", HtmlTooltipPlugin);
#     HtmlTooltipPlugin.prototype = Object.create(mpld3.Plugin.prototype);
#     HtmlTooltipPlugin.prototype.constructor = HtmlTooltipPlugin;
#     HtmlTooltipPlugin.prototype.requiredProps = ["id"];
#     HtmlTooltipPlugin.prototype.defaultProps = {labels:null, hoffset:0, voffset:10};
#     function HtmlTooltipPlugin(fig, props){
#         mpld3.Plugin.call(this, fig, props);
#     };
#
#     HtmlTooltipPlugin.prototype.draw = function(){
#        var obj = mpld3.get_element(this.props.id);
#        var labels = this.props.labels;
#        var tooltip = d3.select("body").append("div")
#                     .attr("class", "mpld3-tooltip")
#                     .style("position", "absolute")
#                     .style("z-index", "10")
#                     .style("visibility", "hidden");
#
#        obj.elements()
#            .on("mouseover", function(d, i){
#                               tooltip.html(labels[i])
#                                      .style("visibility", "visible");})
#            .on("mousemove", function(d, i){
#                     tooltip
#                       .style("top", d3.event.pageY + this.props.voffset + "px")
#                       .style("left",d3.event.pageX + this.props.hoffset + "px");
#                  }.bind(this))
#            .on("mouseout",  function(d, i){
#                            tooltip.style("visibility", "hidden");});
#     };
#
#        mpld3.draw_figure("fig_el3844323435841248781594", {"axes": [{"xlim": [0.0, 1.2], "yscale": "linear", "axesbg": "#FFFFFF", "texts": [{"v_baseline": "hanging", "h_anchor": "middle", "color": "#262626", "text": "coverage", "coordinates": "axes", "zorder": 3, "alpha": 1, "fontsize": 11.0, "position": [0.5, -0.068426197458455532], "rotation": -0.0, "id": "el384432142432"}, {"v_baseline": "auto", "h_anchor": "middle", "color": "#262626", "text": "density", "coordinates": "axes", "zorder": 3, "alpha": 1, "fontsize": 11.0, "position": [-0.070459509408602128, 0.5], "rotation": -90.0, "id": "el384430411904"}], "zoomable": true, "images": [], "xdomain": [0.0, 1.2], "ylim": [0.0, 1.2], "paths": [], "sharey": [], "sharex": [], "axesbgalpha": null, "axes": [{"scale": "linear", "tickformat": null, "grid": {"color": "#CCCCCC", "alpha": 1.0, "dasharray": "10,0", "gridOn": true}, "fontsize": 10.0, "position": "bottom", "nticks": 7, "tickvalues": null}, {"scale": "linear", "tickformat": null, "grid": {"color": "#CCCCCC", "alpha": 1.0, "dasharray": "10,0", "gridOn": true}, "fontsize": 10.0, "position": "left", "nticks": 7, "tickvalues": null}], "lines": [], "markers": [], "id": "el384432143552", "ydomain": [0.0, 1.2], "collections": [{"paths": [[[[0.0, -0.5], [0.13260155, -0.5], [0.25978993539242673, -0.44731684579412084], [0.3535533905932738, -0.3535533905932738], [0.44731684579412084, -0.25978993539242673], [0.5, -0.13260155], [0.5, 0.0], [0.5, 0.13260155], [0.44731684579412084, 0.25978993539242673], [0.3535533905932738, 0.3535533905932738], [0.25978993539242673, 0.44731684579412084], [0.13260155, 0.5], [0.0, 0.5], [-0.13260155, 0.5], [-0.25978993539242673, 0.44731684579412084], [-0.3535533905932738, 0.3535533905932738], [-0.44731684579412084, 0.25978993539242673], [-0.5, 0.13260155], [-0.5, 0.0], [-0.5, -0.13260155], [-0.44731684579412084, -0.25978993539242673], [-0.3535533905932738, -0.3535533905932738], [-0.25978993539242673, -0.44731684579412084], [-0.13260155, -0.5], [0.0, -0.5]], ["M", "C", "C", "C", "C", "C", "C", "C", "C", "Z"]]], "edgecolors": ["#000000"], "edgewidths": [0.3], "offsets": "data01", "yindex": 1, "id": "el384428616392", "pathtransforms": [[4.969039949999533, 0.0, 0.0, 4.969039949999533, 0.0, 0.0]], "pathcoordinates": "display", "offsetcoordinates": "data", "zorder": 1, "xindex": 0, "alphas": [null], "facecolors": ["#081D58", "#1C2D83", "#1C2D83", "#23469C", "#2166AB", "#2166AB", "#2166AB", "#2166AB", "#2166AB", "#2166AB", "#2166AB", "#2166AB", "#1D8BBD", "#32A7C2", "#32A7C2", "#32A7C2", "#32A7C2", "#32A7C2", "#32A7C2", "#32A7C2", "#57BEC0", "#57BEC0", "#84CFBA", "#B8E3B5", "#B8E3B5", "#DAF0B2", "#DAF0B2", "#DAF0B2", "#F1F9BA", "#F1F9BA", "#FFFFD9", "#FFFFD9", "#FFFFD9", "#FFFFD9", "#FFFFD9", "#FFFFD9", "#FFFFD9", "#FFFFD9"]}], "xscale": "linear", "bbox": [0.125, 0.125, 0.62, 0.77500000000000002]}, {"xlim": [0.0, 1.0], "yscale": "linear", "axesbg": "#FFFFFF", "texts": [{"v_baseline": "hanging", "h_anchor": "middle", "color": "#262626", "text": "nr. of restricted dimensions", "coordinates": "axes", "zorder": 3, "alpha": 1, "fontsize": 11.0, "position": [2.4170943304007793, 0.5], "rotation": -90.0, "id": "el384428671776"}], "zoomable": false, "images": [], "xdomain": [0.0, 1.0], "ylim": [0.0, 1.0], "paths": [], "sharey": [], "sharex": [], "axesbgalpha": null, "axes": [{"scale": "linear", "tickformat": "", "grid": {"gridOn": false}, "fontsize": null, "position": "bottom", "nticks": 0, "tickvalues": []}, {"scale": "linear", "tickformat": null, "grid": {"gridOn": false}, "fontsize": 10.0, "position": "right", "nticks": 12, "tickvalues": [0.041666666666666664, 0.125, 0.20833333333333331, 0.29166666666666663, 0.375, 0.45833333333333331, 0.54166666666666663, 0.625, 0.70833333333333326, 0.79166666666666663, 0.875, 0.95833333333333326]}], "lines": [], "markers": [], "id": "el384428615888", "ydomain": [0.0, 1.0], "collections": [{"paths": [[[[0.0, 0.0], [1.0, 0.0], [1.0, 0.08333333333333333], [0.0, 0.08333333333333333], [0.0,  ...

# %%
box1.select(10)
box1.drop_restriction('MitigationEnforcementFactor')
box1.inspect(style='graph')
plt.show()

# %%
ooi_dif = grouped_results[models[0]][1]['BottomUpMitigationRatio_mean'] - grouped_results[models[1]][1]['BottomUpMitigationRatio_mean']

# %%
data = ooi_dif

fig = plt.figure()
ax = fig.add_subplot(111)
ax.plot(np.median(data, axis=0), label = 'mean')
ax.fill_between(np.arange(0, data.shape[1]),np.min(data, axis=0), np.max(data, axis=0), alpha=0.2)
ax.plot(np.percentile(data, 25, axis=0), label='first quartile')
ax.plot(np.percentile(data, 75, axis=0), label='third quartile')

ax.legend()
plt.show()

# %%
temp_outcomes = {'dif':ooi_dif}
results = experiments, temp_outcomes

def classify(data):
    outcome = data['dif'][:,50]
    classes = np.zeros(outcome.shape)
    classes[outcome<-0.02] = 1
    return classes

prim_obj = Prim(results, classify, threshold=0.8)

# %%
box1 = prim_obj.find_box()
box1.show_tradeoff()
mpld3.display()
# Out:
# [INFO/MainProcess] 1000 points remaining, containing 651 cases of interest
# [INFO/MainProcess] mean: 1.0, mass: 0.202, coverage: 0.310291858679, density: 1.0 restricted_dimensions: 8.0
# <style>
#
#             table
#             {
#               border-collapse: collapse;
#             }
#             th
#             {
#               background-color:  rgba(255,255,255,0.6);;;
#             }
#             td
#             {
#               background-color: rgba(255,255,255,0.6);;
#             }
#             table, th, td
#             {
#               font-family:Tahoma, Tahoma, sans-serif;
#               font-size: 16px;
#               border: 1px solid black;
#               text-align: right;
#             }
#
# </style>
#
# <div id="fig_el3844707311284971644889"></div>
# <script>
# function mpld3_load_lib(url, callback){
#   var s = document.createElement('script');
#   s.src = url;
#   s.async = true;
#   s.onreadystatechange = s.onload = callback;
#   s.onerror = function(){console.warn("failed to load library " + url);};
#   document.getElementsByTagName("head")[0].appendChild(s);
# }
#
# if(typeof(mpld3) !== "undefined" && mpld3._mpld3IsLoaded){
#    // already loaded: just create the figure
#    !function(mpld3){
#
#     mpld3.register_plugin("htmltooltip", HtmlTooltipPlugin);
#     HtmlTooltipPlugin.prototype = Object.create(mpld3.Plugin.prototype);
#     HtmlTooltipPlugin.prototype.constructor = HtmlTooltipPlugin;
#     HtmlTooltipPlugin.prototype.requiredProps = ["id"];
#     HtmlTooltipPlugin.prototype.defaultProps = {labels:null, hoffset:0, voffset:10};
#     function HtmlTooltipPlugin(fig, props){
#         mpld3.Plugin.call(this, fig, props);
#     };
#
#     HtmlTooltipPlugin.prototype.draw = function(){
#        var obj = mpld3.get_element(this.props.id);
#        var labels = this.props.labels;
#        var tooltip = d3.select("body").append("div")
#                     .attr("class", "mpld3-tooltip")
#                     .style("position", "absolute")
#                     .style("z-index", "10")
#                     .style("visibility", "hidden");
#
#        obj.elements()
#            .on("mouseover", function(d, i){
#                               tooltip.html(labels[i])
#                                      .style("visibility", "visible");})
#            .on("mousemove", function(d, i){
#                     tooltip
#                       .style("top", d3.event.pageY + this.props.voffset + "px")
#                       .style("left",d3.event.pageX + this.props.hoffset + "px");
#                  }.bind(this))
#            .on("mouseout",  function(d, i){
#                            tooltip.style("visibility", "hidden");});
#     };
#
#        mpld3.draw_figure("fig_el3844707311284971644889", {"axes": [{"xlim": [0.0, 1.2], "yscale": "linear", "axesbg": "#FFFFFF", "texts": [{"v_baseline": "hanging", "h_anchor": "middle", "color": "#262626", "text": "coverage", "coordinates": "axes", "zorder": 3, "alpha": 1, "fontsize": 11.0, "position": [0.5, -0.068426197458455532], "rotation": -0.0, "id": "el384462803744"}, {"v_baseline": "auto", "h_anchor": "middle", "color": "#262626", "text": "density", "coordinates": "axes", "zorder": 3, "alpha": 1, "fontsize": 11.0, "position": [-0.070459509408602128, 0.5], "rotation": -90.0, "id": "el384427814136"}], "zoomable": true, "images": [], "xdomain": [0.0, 1.2], "ylim": [0.0, 1.2], "paths": [], "sharey": [], "sharex": [], "axesbgalpha": null, "axes": [{"scale": "linear", "tickformat": null, "grid": {"color": "#CCCCCC", "alpha": 1.0, "dasharray": "10,0", "gridOn": true}, "fontsize": 10.0, "position": "bottom", "nticks": 7, "tickvalues": null}, {"scale": "linear", "tickformat": null, "grid": {"color": "#CCCCCC", "alpha": 1.0, "dasharray": "10,0", "gridOn": true}, "fontsize": 10.0, "position": "left", "nticks": 7, "tickvalues": null}], "lines": [], "markers": [], "id": "el384470690896", "ydomain": [0.0, 1.2], "collections": [{"paths": [[[[0.0, -0.5], [0.13260155, -0.5], [0.25978993539242673, -0.44731684579412084], [0.3535533905932738, -0.3535533905932738], [0.44731684579412084, -0.25978993539242673], [0.5, -0.13260155], [0.5, 0.0], [0.5, 0.13260155], [0.44731684579412084, 0.25978993539242673], [0.3535533905932738, 0.3535533905932738], [0.25978993539242673, 0.44731684579412084], [0.13260155, 0.5], [0.0, 0.5], [-0.13260155, 0.5], [-0.25978993539242673, 0.44731684579412084], [-0.3535533905932738, 0.3535533905932738], [-0.44731684579412084, 0.25978993539242673], [-0.5, 0.13260155], [-0.5, 0.0], [-0.5, -0.13260155], [-0.44731684579412084, -0.25978993539242673], [-0.3535533905932738, -0.3535533905932738], [-0.25978993539242673, -0.44731684579412084], [-0.13260155, -0.5], [0.0, -0.5]], ["M", "C", "C", "C", "C", "C", "C", "C", "C", "Z"]]], "edgecolors": ["#000000"], "edgewidths": [0.3], "offsets": "data01", "yindex": 1, "id": "el384472181392", "pathtransforms": [[4.969039949999533, 0.0, 0.0, 4.969039949999533, 0.0, 0.0]], "pathcoordinates": "display", "offsetcoordinates": "data", "zorder": 1, "xindex": 0, "alphas": [null], "facecolors": ["#081D58", "#243392", "#243392", "#243392", "#243392", "#243392", "#243392", "#243392", "#243392", "#243392", "#243392", "#243392", "#243392", "#243392", "#225DA7", "#1D90BF", "#40B5C3", "#7ECCBB", "#7ECCBB", "#7ECCBB", "#C6E8B4", "#C6E8B4", "#C6E8B4", "#ECF7B1", "#FFFFD9"]}], "xscale": "linear", "bbox": [0.125, 0.125, 0.62, 0.77500000000000002]}, {"xlim": [0.0, 1.0], "yscale": "linear", "axesbg": "#FFFFFF", "texts": [{"v_baseline": "hanging", "h_anchor": "middle", "color": "#262626", "text": "nr. of restricted dimensions", "coordinates": "axes", "zorder": 3, "alpha": 1, "fontsize": 11.0, "position": [2.1055107526881685, 0.5], "rotation": -90.0, "id": "el384462582672"}], "zoomable": false, "images": [], "xdomain": [0.0, 1.0], "ylim": [0.0, 1.0], "paths": [], "sharey": [], "sharex": [], "axesbgalpha": null, "axes": [{"scale": "linear", "tickformat": "", "grid": {"gridOn": false}, "fontsize": null, "position": "bottom", "nticks": 0, "tickvalues": []}, {"scale": "linear", "tickformat": null, "grid": {"gridOn": false}, "fontsize": 10.0, "position": "right", "nticks": 9, "tickvalues": [0.055555555555555552, 0.16666666666666666, 0.27777777777777779, 0.38888888888888884, 0.5, 0.61111111111111116, 0.7222222222222221, 0.83333333333333326, 0.94444444444444442]}], "lines": [], "markers": [], "id": "el384463044336", "ydomain": [0.0, 1.0], "collections": [{"paths": [[[[0.0, 0.0], [1.0, 0.0], [1.0, 0.1111111111111111], [0.0, 0.1111111111111111], [0.0, 0.0]], ["M", "L", "L", "L", "L"]], [[[0.0, 0.1111111111111111], [1.0, 0.1111111111111111], [1.0, 0.2222222222222222], [0.0, 0.2222222222222222], [0.0, 0.1111111111111111] ...

# %%
box1.inspect(8, style='graph')
plt.show()
