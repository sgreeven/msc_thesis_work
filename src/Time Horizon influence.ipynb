# %% [markdown]
# # Single uncertainty sensititivy analysis - Time Horizon Uncertainty
# * EMA Society's response to climate change
# * Name: Sebastiaan Greeven
# * Date: 27-3-2015
# #### Introduction
# This notebook contains the single uncertainty sensitivity analysis of the time horizon uncertainty.
#
# 1. Initialisation of the analysis
# 2. Visualisation of the sensitivity analysis
# 3. PRIM analysis

# %% [markdown]
# #1. Initialisation of the analysis

# %%
import analysis
import sys
sys.path.append(r'C:\Users\Sebas\Documents\GitHub\EMAworkbench\src')

# %%
% matplotlib inline

import seaborn as sns
import matplotlib.pyplot as plt

sns.set_style('whitegrid')
sns.set_palette("deep")

# fig = plt.figure()
# ax = fig.add_subplot(111)
# plt.show()

# %%
import numpy as np

from analysis.plotting import lines, envelopes
from analysis.plotting_util import VIOLIN, KDE
from expWorkbench import load_results
from expWorkbench import ema_logging

# %%
import matplotlib.pyplot as plt

from analysis.pairs_plotting import pairs_lines, pairs_scatter, pairs_density
from expWorkbench.util import load_results

# ema_logging.log_to_stderr(level=ema_logging.DEFAULT_LEVEL)

# %%
from analysis import prim
from analysis.prim import Prim
from expWorkbench import ema_logging

# %%
ema_logging.log_to_stderr(ema_logging.INFO)

results = load_results(r'./data/time horizon 1000 exp 100 rep.tar.gz')
# Out:
# [INFO/MainProcess] results loaded succesfully from ./data/time horizon 1000 exp 100 rep.tar.gz

# %% [markdown]
# #2. Visualisation of the sensitivity analysis

# %%
experiments, outcomes = results

models = set(experiments['model'])

grouped_results = {}
for model in models:
    logical = experiments['model']==model
    
    temp_experiments = experiments[logical]
    temp_outcomes = {key:value[logical] for key, value in outcomes.items()}
    grouped_results[model] = temp_experiments, temp_outcomes

oois = outcomes.keys()
    
for ooi in oois:
    models = list(models)
    ooi_dif = grouped_results[models[0]][1][ooi] - grouped_results[models[1]][1][ooi]
    fig = plt.figure()
    ax = fig.add_subplot(111)
    ax.hist(ooi_dif[:,-1], bins=20)
    ax.set_ylabel(ooi)
    ax.set_xlabel('Difference')
    plt.show()
    envelopes(results, group_by='model', outcomes_to_show=ooi, fill=True, density='kde')
# Out:
# C:\Users\Sebas\Documents\GitHub\EMAworkbench\src\analysis\plotting_util.py:445: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if time==None:

# %% [markdown]
# #3. PRIM analysis

# %%
import numpy.lib.recfunctions as rf

# %%
experiments =  rf.drop_fields(grouped_results[models[0]][0], 'model')

# %%
ooi_dif = grouped_results[models[0]][1]['CumulativeGHGreduction_mean'] - grouped_results[models[1]][1]['CumulativeGHGreduction_mean']

# %%
data = ooi_dif

fig = plt.figure()
ax = fig.add_subplot(111)
ax.plot(np.median(data, axis=0), label = 'mean')
ax.fill_between(np.arange(0, data.shape[1]),np.min(data, axis=0), np.max(data, axis=0), alpha=0.2)
ax.plot(np.percentile(data, 25, axis=0), label='first quartile')
ax.plot(np.percentile(data, 75, axis=0), label='third quartile')

ax.legend()
plt.show()

# %%
temp_outcomes = {'dif':ooi_dif}
results = experiments, temp_outcomes

def classify(data):
    outcome = data['dif'][:,-1]
    classes = np.zeros(outcome.shape)
    classes[outcome>8] = 1
    return classes

prim_obj = Prim(results, classify, threshold=0.8)

# %%
box1 = prim_obj.find_box()
box1.show_ppt()
plt.show()
box1.show_tradeoff()
plt.show()
# Out:
# [INFO/MainProcess] 1000 points remaining, containing 592 cases of interest
# [INFO/MainProcess] mean: 1.0, mass: 0.114, coverage: 0.192567567568, density: 1.0 restricted_dimensions: 7.0

# %%
box1.inspect(3)
box1.inspect(7)
# Out:
# coverage    0.609797
# density     0.807606
# mass        0.447000
# mean        0.807606
# res dim     2.000000
# Name: 3, dtype: float64
#
#                                           box 3
#                                             min           max     qp values
# ClimateDisasterIncreaseMitigation  set([False])  set([False])  2.221995e-16
# SDTimeHorizonDistribution            0.01835166      18.03988   0.003151264
#
# coverage    0.540541
# density     0.886427
# mass        0.361000
# mean        0.886427
# res dim     3.000000
# Name: 7, dtype: float64
#                                           box 7
#                                             min           max     qp values
# ClimateDisasterIncreaseMitigation  set([False])  set([False])  6.739829e-20
# SDTimeHorizonDistribution            0.01835166      17.19088  2.859338e-05
# ImpactFactor                          0.8001594      1.149787   0.000314656

# %%
box1.select(7)
prim_obj.show_boxes()
plt.show()

# %%
from analysis.plotting_util import BOXPLOT

indices = box1.yi

all_indices = np.arange(experiments.shape[0])
logical = np.ones((all_indices.shape[0],), dtype=np.bool)
logical[indices] = 0
out_box = all_indices[logical]

gs = {}
gs['in box'] = indices
gs['out box'] = out_box
# gs['all'] = all_indices

envelopes(results, outcomes_to_show=['dif'], group_by='index', grouping_specifiers=gs, fill=True, density=BOXPLOT)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-22-7a617c0ded40> in <module>()
#      13 # gs['all'] = all_indices
#      14
# ---> 15 envelopes(results, outcomes_to_show=['dif'], group_by='index', grouping_specifiers=gs, fill=True, density=BOXPLOT)
#      16 plt.show()
#
# C:\Users\Sebas\Documents\GitHub\EMAworkbench\src\analysis\plotting.pyc in envelopes(results, outcomes_to_show, group_by, grouping_specifiers, density, fill, legend, titles, ylabels, log)
#     111
#     112     prepared_data = prepare_data(results, outcomes_to_show, group_by,
# --> 113                                  grouping_specifiers)
#     114     outcomes, outcomes_to_show, time, grouping_labels = prepared_data
#     115
#
# C:\Users\Sebas\Documents\GitHub\EMAworkbench\src\analysis\plotting_util.pyc in prepare_data(results, outcomes_to_show, group_by, grouping_specifiers, filter_scalar)
#     662
#     663         outcomes = group_results(experiments, outcomes, group_by,\
# --> 664                                  grouping_specifiers)
#     665
#     666         new_outcomes = {}
#
# C:\Users\Sebas\Documents\GitHub\EMAworkbench\src\analysis\plotting_util.pyc in group_results(experiments, outcomes, group_by, grouping_specifiers)
#     513         group_outcomes = {}
#     514         for key, value in outcomes.items():
# --> 515             value = value[logical]
#     516             group_outcomes[key] = value
#     517         groups[grouping_specifier] = (experiments[logical], group_outcomes)
#
# IndexError: index 1000 is out of bounds for axis 0 with size 1000

# %%
ooi_dif = grouped_results[models[0]][1]['AnnualGHGreduction_mean'] - grouped_results[models[1]][1]['AnnualGHGreduction_mean']

# %%
data = ooi_dif

fig = plt.figure()
ax = fig.add_subplot(111)
ax.plot(np.median(data, axis=0), label = 'mean')
ax.fill_between(np.arange(0, data.shape[1]),np.min(data, axis=0), np.max(data, axis=0), alpha=0.2)
ax.plot(np.percentile(data, 25, axis=0), label='first quartile')
ax.plot(np.percentile(data, 75, axis=0), label='third quartile')

ax.legend()
plt.show()

# %%
temp_outcomes = {'dif':ooi_dif}
results = experiments, temp_outcomes

def classify(data):
    outcome = data['dif'][:,-1]
    classes = np.zeros(outcome.shape)
    classes[outcome<-10] = 1
    return classes

prim_obj = Prim(results, classify, threshold=0.8)

# %%
box1 = prim_obj.find_box()
box1.show_ppt()
plt.show()
box1.show_tradeoff()
plt.show()
# Out:
# [INFO/MainProcess] 1000 points remaining, containing 755 cases of interest
# [INFO/MainProcess] mean: 1.0, mass: 0.298, coverage: 0.394701986755, density: 1.0 restricted_dimensions: 4.0

# %%
box1.inspect(3)
box1.inspect(11)
# Out:
# coverage    0.943046
# density     0.831776
# mass        0.856000
# mean        0.831776
# res dim     1.000000
# Name: 3, dtype: float64
#
#                  box 3
#                    min       max     qp values
# ImpactFactor  0.800159  1.142459  3.475868e-08
#
# coverage    0.401325
# density     0.996711
# mass        0.304000
# mean        0.996711
# res dim     3.000000
# Name: 11, dtype: float64
#                                 box 11
#                                    min                   max     qp values
# ImpactFactor                 0.8001594              1.050735  1.840151e-20
# GameTheory        set(["Cooperative"])  set(["Cooperative"])  1.142049e-05
# DemocraticValue5          0.0009320243             0.9420594     0.4244099

# %%
box1.select(11)
box1.drop_restriction('DemocraticValue5')

# %%
prim_obj.show_boxes()
plt.show()

# %%
temp_outcomes = {'dif':ooi_dif}
results = experiments, temp_outcomes

def classify(data):
    outcome = data['dif'][:,50]
    classes = np.zeros(outcome.shape)
    classes[outcome>20] = 1
    return classes

prim_obj = Prim(results, classify, threshold=0.8)

# %%
box1 = prim_obj.find_box()
box1.show_ppt()
plt.show()
box1.show_tradeoff()
plt.show()
# Out:
# [INFO/MainProcess] 1000 points remaining, containing 605 cases of interest
# [INFO/MainProcess] mean: 1.0, mass: 0.151, coverage: 0.24958677686, density: 1.0 restricted_dimensions: 6.0

# %%
box1.inspect(8)
# Out:
# coverage    0.882645
# density     0.807867
# mass        0.661000
# mean        0.807867
# res dim     1.000000
# Name: 8, dtype: float64
#
#                               box 8
#                                 min       max     qp values
# SDTimeHorizonDistribution  0.018352  13.21742  3.007550e-29
